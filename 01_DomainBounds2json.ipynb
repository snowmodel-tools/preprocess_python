# %%
# create a JSON with bounding parameters for each modeling domain
# get ncols, nrows, ll corner coordinates, and cell size from domain ascii files.

# %%
WY = {
    "name": 'WY',
    "Bbox": {'latmax' : 44.582480,'latmin' : 42.363116,'lonmax': -109.477849,'lonmin': -111.155208,},
    "st": "2011-09-01", 
    "ed": "2016-09-30",
    "stn_proj": 'epsg:4326',
    "mod_proj": 'epsg:32612',
    "ncols": '1382',
    "nrows": '2476',
    "xll": '487200',
    "yll": '4690100', 
    "cellsize": '100'
}

OR = {
    "name": 'OR',
    "Bbox": {'latmax' : 44.74,'latmin' : 43.645,'lonmax': -121.11,'lonmin': -122.11,},
    "st": "2011-09-01", 
    "ed": "2016-09-30",
    "stn_proj": 'epsg:4326',
    "mod_proj": 'epsg:32610', 
    "ncols": '821',
    "nrows": '1231',
    "xll": '570400',
    "yll": '4832800', 
    "cellsize": '100'
}

GOA = {
    "name": 'GOA',
    "Bbox": {'latmax' : 60.8622,'latmin' : 56.2819,'lonmax': -122.7722,'lonmin': -156.8955,},
    "st": "2011-09-01", 
    "ed": "2016-09-30",
    "stn_proj": 'epsg:4326',
    "mod_proj": 'epsg:3338', 
    "ncols": '1',
    "nrows": '1',
    "xll": '1',
    "yll": '1', 
    "cellsize": '1000'
}

UT = {
    "name": 'UT',
    "Bbox": {'latmax' : 40.7119,'latmin' : 40.4407,'lonmax': -111.461,'lonmin': -111.7986,},
    "st": "2011-09-01", 
    "ed": "2016-09-30",
    "stn_proj": 'epsg:4326',
    "mod_proj": 'epsg:32612',
    "ncols": '960',
    "nrows": '1012',
    "xll": '432270',
    "yll": '4476750', 
    "cellsize": '30'
}

WA = {
    "name": 'WA',
    "Bbox": {'latmax' : 48.9,'latmin' : 47.8299,'lonmax': -119.769,'lonmin': -121.1,},
    "st": "2011-10-01", 
    "ed": "2016-09-30",
    "stn_proj": 'epsg:4326',
    "mod_proj": 'epsg:32610',
    "ncols": '2052',
    "nrows": '2446',
    "xll": '639200',
    "yll": '5299100', 
    "cellsize": '50'
}


CA = {
    "name": 'CA',
    "Bbox": {'latmax' : 39.7,'latmin' : 38.4,'lonmax': -119.66,'lonmin': -120.85,},
    "st": "2011-09-01", 
    "ed": "2016-09-30",
    "stn_proj": 'epsg:4326',
    "mod_proj": 'epsg:32611',
    "ncols": '2164',
    "nrows": '2962',
    "xll": '163750',
    "yll": '4253500', 
    "cellsize": '50'
}

HJA = {
    "name": 'HJA',
    "Bbox": {'latmax' : 44.28115,'latmin' : 44.19873,'lonmax': -122.10189,'lonmin': -122.26163,},
    "st": "2011-09-01", 
    "ed": "2016-09-30",
    "stn_proj": 'epsg:4326',
    "mod_proj": 'epsg:32610',
    "ncols": '429',
    "nrows": '310',    
    "xll": '558900',
    "yll": '4894200', 
    "cellsize": '30'
}

CO = {
    "name": 'CO',
    "Bbox": {'latmax' : 40.8,'latmin' : 37.1,'lonmax': -104.8,'lonmin': -108.5,},
    "st": "2011-09-01", 
    "ed": "2016-09-30",
    "stn_proj": 'epsg:4326',
    "mod_proj": 'epsg:32613',
    "ncols": '3289',
    "nrows": '4166',
    "xll": '188900',
    "yll": '4105900', 
    "cellsize": '100'
}

ID = {
    "name": 'ID',
    "Bbox": {'latmax' : 44.483224,'latmin' : 43.559833,'lonmax': -114.934861,'lonmin': -116.462681,},
    "st": "2011-09-01", 
    "ed": "2016-09-30",
    "stn_proj": 'epsg:4326',
    "mod_proj": 'epsg:32612',
    "ncols": '2567',
    "nrows": '2192',
    "xll": '58750',
    "yll": '4830500', 
    "cellsize": '50'
}

AK = {
    "name": 'AK',
    "Bbox": {'latmax' : 61.0179627,'latmin' : 60.67770498,'lonmax': -148.7578855597,'lonmin': -149.38460973,},
    "st": "2011-09-01", 
    "ed": "2016-09-30",
    "stn_proj": 'epsg:4326',
    "mod_proj": 'epsg:32607',
    "ncols": '',
    "nrows": '',
    "xll": '',
    "yll": '', 
    "cellsize": '30'
}

CO_N = {
    "name": 'CO_N',
    "Bbox": {'latmax' : 40.194217,'latmin' : 38.370328,'lonmax': -105.407231,'lonmin': -107.538579,},
    "st": "2011-09-01", 
    "ed": "2016-09-30",
    "stn_proj": 'epsg:4326',
    "mod_proj": 'epsg:32613',
    "ncols": '1872',
    "nrows": '2056',
    "xll": '278200',
    "yll": '4246900', 
    "cellsize": '100'
}

CO_S = {
    "name": 'CO_S',
    "Bbox": {'latmax' : 38.038433,'latmin' : 37.304722,'lonmax': -106.463801,'lonmin': -108.106257,},
    "st": "2011-09-01", 
    "ed": "2016-09-30",
    "stn_proj": 'epsg:4326',
    "mod_proj": 'epsg:32613',
    "ncols": '1470',
    "nrows": '851',
    "xll": '224600',
    "yll": '4129600', 
    "cellsize": '100'
}

NH = {
    "name": 'NH',
    "Bbox": {'latmax' : 44.328173,'latmin' : 43.901758,'lonmax': -71.009589,'lonmin': -71.754594,},
    "st": "2011-10-01", 
    "ed": "2016-09-30",
    "stn_proj": 'epsg:4326',
    "mod_proj": 'epsg:32619',
    "ncols": '2034',
    "nrows": '1637',
    "xll": '278760',
    "yll": '4862910', 
    "cellsize": '30'
}

WA_SQ = {
    "name": 'WA_SQ',
    "Bbox": {'latmax' : 47.550,'latmin' : 47.189,'lonmax': -121.183,'lonmin': -121.740,},
    "st": "2011-10-01",
    "ed": "2016-09-30",
    "stn_proj": 'epsg:4326',
    "mod_proj": 'epsg:32610',
    "ncols": '1429',
    "nrows": '1366',
    "xll": '594780',
    "yll": '5226930',
    "cellsize": '30'
}

MT = {
    "name": 'MT',
    "Bbox": {'latmax' : 45.465,'latmin' : 44.490,'lonmax': -110.564,'lonmin': -111.676,},
    "st": "2011-10-01",
    "ed": "2016-09-30",
    "stn_proj": 'epsg:4326',
    "mod_proj": 'epsg:32612',
    "ncols": '1769',
    "nrows": '2170',
    "xll": '446250',
    "yll": '4926350',
    "cellsize": '50'
}

SUS = {
    "name": 'SUS',
    "Bbox": {'latmax' : 61.9,'latmin' : 61.68,'lonmax': -149,'lonmin': -149.35,},
    "st": "2016-10-01",
    "ed": "2018-09-30",
    "stn_proj": 'epsg:4326',
    "mod_proj": 'epsg:3338',
    "ncols": '408',
    "nrows": '518',
    "xll": '243400',
    "yll": '1308750',
    "cellsize": '50'
}

CHENA = {
    "name": 'CHENA',
    "Bbox": {'latmax' : 65.3,'latmin' : 64.7,'lonmax': -144.5,'lonmin': -146.7,},
    "st": "2016-10-01",
    "ed": "2018-09-30",
    "stn_proj": 'epsg:4326',
    "mod_proj": 'epsg:3338',
    "ncols": '744',
    "nrows": '531',
    "xll": '339900',
    "yll": '1656600',
    "cellsize": '150'
}

TEK = {
    "name": 'TEK',
    "Bbox": {'latmax' : 64.369,'latmin' : 63.164,'lonmax': -149,'lonmin': -150,},
    "st": "2011-10-01",
    "ed": "2016-09-30",
    "stn_proj": 'epsg:4326',
    "mod_proj": 'epsg:3338',
    "ncols": '583',
    "nrows": '1377',
    "xll": '192800',
    "yll": '1472100',
    "cellsize": '100'
}

CHU = {
    "name": 'CHU',
    "Bbox": {'latmax' : 61.15,'latmin' : 60.55,'lonmax': -148.6,'lonmin': -149.7,},
    "st": "2015-10-01",
    "ed": "2019-09-30",
    "stn_proj": 'epsg:4326',
    "mod_proj": 'epsg:3338',
    "ncols": '644',
    "nrows": '713',
    "xll": '230500',
    "yll": '1181400',
    "cellsize": '100'
}

MH = {
    "name": 'MH',
    "Bbox": {'latmax' : 45.55,'latmin' : 45.16,'lonmax': -121.48,'lonmin': -121.93,},
    "st": "2015-10-01",
    "ed": "2019-09-30",
    "stn_proj": 'epsg:4326',
    "mod_proj": 'epsg:32610',
    "ncols": '720',
    "nrows": '879',
    "xll": '583500',
    "yll": '5001250',
    "cellsize": '50'
}

ST = {
    "name": 'ST',
    "Bbox": {'latmax' : 44.3,'latmin' : 43.4,'lonmax': -114.25,'lonmin': -115.5,},
    "st": "2015-10-01",
    "ed": "2018-08-31",
    "stn_proj": 'epsg:4326',
    "mod_proj": 'epsg:32611',
    "ncols": '1031',
    "nrows": '1026',
    "xll": '619600',
    "yll": '4806300',
    "cellsize": '100'
}

BR = {
    "name": 'BR',
    "Bbox": {'latmax' : 39.718,'latmin' : 39.313,'lonmax': -105.73,'lonmin': -106.286,},
    "st": "2015-10-01",
    "ed": "2018-08-31",
    "stn_proj": 'epsg:4326',
    "mod_proj": 'epsg:32613',
    "ncols": '1611',
    "nrows": '1517',
    "xll": '389130',
    "yll": '4351740',
    "cellsize": '30'
}

CSO_domains = {
    "WY": WY,
    "OR": OR,
    "GOA":GOA,
    "UT": UT,
    "WA": WA,
    "CA":CA,
    "HJA":HJA,
    "CO":CO,
    "CO_N":CO_N,
    "CO_S":CO_S,
    "AK":AK,
    "ID":ID,
    "NH":NH,
    "WA_SQ":WA_SQ,
    "MT":MT,
    "SUS":SUS,
    "CHENA":CHENA,
    "TEK":TEK,
    "CHU":CHU,
    "MH":MH,
    "ST":ST,
    "BR":BR
}

# %%
display(CSO_domains)
CSO_domains.keys()
# Out:
# {'WY': {'name': 'WY',
#   'Bbox': {'latmax': 44.58248,
#    'latmin': 42.363116,
#    'lonmax': -109.477849,
#    'lonmin': -111.155208},
#   'st': '2011-09-01',
#   'ed': '2016-09-30',
#   'stn_proj': 'epsg:4326',
#   'mod_proj': 'epsg:32612',
#   'ncols': '1382',
#   'nrows': '2476',
#   'xll': '487200',
#   'yll': '4690100',
#   'cellsize': '100'},
#  'OR': {'name': 'OR',
#   'Bbox': {'latmax': 44.74,
#    'latmin': 43.645,
#    'lonmax': -121.11,
#    'lonmin': -122.11},
#   'st': '2011-09-01',
#   'ed': '2016-09-30',
#   'stn_proj': 'epsg:4326',
#   'mod_proj': 'epsg:32610',
#   'ncols': '821',
#   'nrows': '1231',
#   'xll': '570400',
#   'yll': '4832800',
#   'cellsize': '100'},
#  'GOA': {'name': 'GOA',
#   'Bbox': {'latmax': 60.8622,
#    'latmin': 56.2819,
#    'lonmax': -122.7722,
#    'lonmin': -156.8955},
#   'st': '2011-09-01',
#   'ed': '2016-09-30',
#   'stn_proj': 'epsg:4326',
#   'mod_proj': 'epsg:3338',
#   'ncols': '1',
#   'nrows': '1',
#   'xll': '1',
#   'yll': '1',
#   'cellsize': '1000'},
#  'UT': {'name': 'UT',
#   'Bbox': {'latmax': 40.7119,
#    'latmin': 40.4407,
#    'lonmax': -111.461,
#    'lonmin': -111.7986},
#   'st': '2011-09-01',
#   'ed': '2016-09-30',
#   'stn_proj': 'epsg:4326',
#   'mod_proj': 'epsg:32612',
#   'ncols': '960',
#   'nrows': '1012',
#   'xll': '432270',
#   'yll': '4476750',
#   'cellsize': '30'},
#  'WA': {'name': 'WA',
#   'Bbox': {'latmax': 48.9,
#    'latmin': 47.8299,
#    'lonmax': -119.769,
#    'lonmin': -121.1},
#   'st': '2011-10-01',
#   'ed': '2016-09-30',
#   'stn_proj': 'epsg:4326',
#   'mod_proj': 'epsg:32610',
#   'ncols': '2052',
#   'nrows': '2446',
#   'xll': '639200',
#   'yll': '5299100',
#   'cellsize': '50'},
#  'CA': {'name': 'CA',
#   'Bbox': {'latmax': 39.7,
#    'latmin': 38.4,
#    'lonmax': -119.66,
#    'lonmin': -120.85},
#   'st': '2011-09-01',
#   'ed': '2016-09-30',
#   'stn_proj': 'epsg:4326',
#   'mod_proj': 'epsg:32611',
#   'ncols': '2164',
#   'nrows': '2962',
#   'xll': '163750',
#   'yll': '4253500',
#   'cellsize': '50'},
#  'HJA': {'name': 'HJA',
#   'Bbox': {'latmax': 44.28115,
#    'latmin': 44.19873,
#    'lonmax': -122.10189,
#    'lonmin': -122.26163},
#   'st': '2011-09-01',
#   'ed': '2016-09-30',
#   'stn_proj': 'epsg:4326',
#   'mod_proj': 'epsg:32610',
#   'ncols': '429',
#   'nrows': '310',
#   'xll': '558900',
#   'yll': '4894200',
#   'cellsize': '30'},
#  'CO': {'name': 'CO',
#   'Bbox': {'latmax': 40.8, 'latmin': 37.1, 'lonmax': -104.8, 'lonmin': -108.5},
#   'st': '2011-09-01',
#   'ed': '2016-09-30',
#   'stn_proj': 'epsg:4326',
#   'mod_proj': 'epsg:32613',
#   'ncols': '3289',
#   'nrows': '4166',
#   'xll': '188900',
#   'yll': '4105900',
#   'cellsize': '100'},
#  'CO_N': {'name': 'CO_N',
#   'Bbox': {'latmax': 40.194217,
#    'latmin': 38.370328,
#    'lonmax': -105.407231,
#    'lonmin': -107.538579},
#   'st': '2011-09-01',
#   'ed': '2016-09-30',
#   'stn_proj': 'epsg:4326',
#   'mod_proj': 'epsg:32613',
#   'ncols': '1872',
#   'nrows': '2056',
#   'xll': '278200',
#   'yll': '4246900',
#   'cellsize': '100'},
#  'CO_S': {'name': 'CO_S',
#   'Bbox': {'latmax': 38.038433,
#    'latmin': 37.304722,
#    'lonmax': -106.463801,
#    'lonmin': -108.106257},
#   'st': '2011-09-01',
#   'ed': '2016-09-30',
#   'stn_proj': 'epsg:4326',
#   'mod_proj': 'epsg:32613',
#   'ncols': '1470',
#   'nrows': '851',
#   'xll': '224600',
#   'yll': '4129600',
#   'cellsize': '100'},
#  'AK': {'name': 'AK',
#   'Bbox': {'latmax': 61.0179627,
#    'latmin': 60.67770498,
#    'lonmax': -148.7578855597,
#    'lonmin': -149.38460973},
#   'st': '2011-09-01',
#   'ed': '2016-09-30',
#   'stn_proj': 'epsg:4326',
#   'mod_proj': 'epsg:32607',
#   'ncols': '',
#   'nrows': '',
#   'xll': '',
#   'yll': '',
#   'cellsize': '30'},
#  'ID': {'name': 'ID',
#   'Bbox': {'latmax': 44.483224,
#    'latmin': 43.559833,
#    'lonmax': -114.934861,
#    'lonmin': -116.462681},
#   'st': '2011-09-01',
#   'ed': '2016-09-30',
#   'stn_proj': 'epsg:4326',
#   'mod_proj': 'epsg:32612',
#   'ncols': '2567',
#   'nrows': '2192',
#   'xll': '58750',
#   'yll': '4830500',
#   'cellsize': '50'},
#  'NH': {'name': 'NH',
#   'Bbox': {'latmax': 44.328173,
#    'latmin': 43.901758,
#    'lonmax': -71.009589,
#    'lonmin': -71.754594},
#   'st': '2011-10-01',
#   'ed': '2016-09-30',
#   'stn_proj': 'epsg:4326',
#   'mod_proj': 'epsg:32619',
#   'ncols': '2034',
#   'nrows': '1637',
#   'xll': '278760',
#   'yll': '4862910',
#   'cellsize': '30'},
#  'WA_SQ': {'name': 'WA_SQ',
#   'Bbox': {'latmax': 47.55,
#    'latmin': 47.189,
#    'lonmax': -121.183,
#    'lonmin': -121.74},
#   'st': '2011-10-01',
#   'ed': '2016-09-30',
#   'stn_proj': 'epsg:4326',
#   'mod_proj': 'epsg:32610',
#   'ncols': '1429',
#   'nrows': '1366',
#   'xll': '594780',
#   'yll': '5226930',
#   'cellsize': '30'},
#  'MT': {'name': 'MT',
#   'Bbox': {'latmax': 45.465,
#    'latmin': 44.49,
#    'lonmax': -110.564,
#    'lonmin': -111.676},
#   'st': '2011-10-01',
#   'ed': '2016-09-30',
#   'stn_proj': 'epsg:4326',
#   'mod_proj': 'epsg:32612',
#   'ncols': '1769',
#   'nrows': '2170',
#   'xll': '446250',
#   'yll': '4926350',
#   'cellsize': '50'},
#  'SUS': {'name': 'SUS',
#   'Bbox': {'latmax': 61.9, 'latmin': 61.68, 'lonmax': -149, 'lonmin': -149.35},
#   'st': '2016-10-01',
#   'ed': '2018-09-30',
#   'stn_proj': 'epsg:4326',
#   'mod_proj': 'epsg:3338',
#   'ncols': '408',
#   'nrows': '518',
#   'xll': '243400',
#   'yll': '1308750',
#   'cellsize': '50'},
#  'CHENA': {'name': 'CHENA',
#   'Bbox': {'latmax': 65.3, 'latmin': 64.7, 'lonmax': -144.5, 'lonmin': -146.7},
#   'st': '2016-10-01',
#   'ed': '2018-09-30',
#   'stn_proj': 'epsg:4326',
#   'mod_proj': 'epsg:3338',
#   'ncols': '744',
#   'nrows': '531',
#   'xll': '339900',
#   'yll': '1656600',
#   'cellsize': '150'},
#  'TEK': {'name': 'TEK',
#   'Bbox': {'latmax': 64.369, 'latmin': 63.164, 'lonmax': -149, 'lonmin': -150},
#   'st': '2011-10-01',
#   'ed': '2016-09-30',
#   'stn_proj': 'epsg:4326',
#   'mod_proj': 'epsg:3338',
#   'ncols': '583',
#   'nrows': '1377',
#   'xll': '192800',
#   'yll': '1472100',
#   'cellsize': '100'},
#  'CHU': {'name': 'CHU',
#   'Bbox': {'latmax': 61.15,
#    'latmin': 60.55,
#    'lonmax': -148.6,
#    'lonmin': -149.7},
#   'st': '2015-10-01',
#   'ed': '2019-09-30',
#   'stn_proj': 'epsg:4326',
#   'mod_proj': 'epsg:3338',
#   'ncols': '644',
#   'nrows': '713',
#   'xll': '230500',
#   'yll': '1181400',
#   'cellsize': '100'},
#  'MH': {'name': 'MH',
#   'Bbox': {'latmax': 45.55,
#    'latmin': 45.16,
#    'lonmax': -121.48,
#    'lonmin': -121.93},
#   'st': '2015-10-01',
#   'ed': '2019-09-30',
#   'stn_proj': 'epsg:4326',
#   'mod_proj': 'epsg:32610',
#   'ncols': '720',
#   'nrows': '879',
#   'xll': '583500',
#   'yll': '5001250',
#   'cellsize': '50'},
#  'ST': {'name': 'ST',
#   'Bbox': {'latmax': 44.3,
#    'latmin': 43.4,
#    'lonmax': -114.25,
#    'lonmin': -115.5},
#   'st': '2015-10-01',
#   'ed': '2018-08-31',
#   'stn_proj': 'epsg:4326',
#   'mod_proj': 'epsg:32611',
#   'ncols': '1031',
#   'nrows': '1026',
#   'xll': '619600',
#   'yll': '4806300',
#   'cellsize': '100'},
#  'BR': {'name': 'BR',
#   'Bbox': {'latmax': 39.718,
#    'latmin': 39.313,
#    'lonmax': -105.73,
#    'lonmin': -106.286},
#   'st': '2015-10-01',
#   'ed': '2018-08-31',
#   'stn_proj': 'epsg:4326',
#   'mod_proj': 'epsg:32613',
#   'ncols': '1611',
#   'nrows': '1517',
#   'xll': '389130',
#   'yll': '4351740',
#   'cellsize': '30'}}
# dict_keys(['WY', 'OR', 'GOA', 'UT', 'WA', 'CA', 'HJA', 'CO', 'CO_N', 'CO_S', 'AK', 'ID', 'NH', 'WA_SQ', 'MT', 'SUS', 'CHENA', 'TEK', 'CHU', 'MH', 'ST', 'BR'])

# %%
import json
json = json.dumps(CSO_domains)
f = open('/nfs/depot/cce_u1/hill/dfh/github/snowmodel_tools/preprocess_python/CSO_domains.json',"w")
f.write(json)
f.close()

# %%
# #save baseline .par file
# import json

# json = json.dumps(CSO_domains)
# f = open('/nfs/attic/dfh/Aragon2/CSOdata/CSO_domains.json',"w")
# f.write(json)
# f.close()
